# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
    return x*np.sin(x)

y_th = np.cos(x)

x = np.linspace(0, 10, 50)
y = func(x)
y_diff = y - y_th

plt.plot(x, y)
plt.plot(x, y_diff)
plt.grid()
